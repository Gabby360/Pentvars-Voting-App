-- %% [markdown]
-- # [VotingSystem]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [VotingSystem]    Script Date: 3/25/2025 5:25:18 PM ******/
CREATE DATABASE [VotingSystem]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'VotingSystem', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\VotingSystem.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'VotingSystem_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\VotingSystem_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [VotingSystem] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [VotingSystem].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [VotingSystem] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [VotingSystem] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [VotingSystem] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [VotingSystem] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [VotingSystem] SET ARITHABORT OFF 
GO
ALTER DATABASE [VotingSystem] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [VotingSystem] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [VotingSystem] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [VotingSystem] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [VotingSystem] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [VotingSystem] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [VotingSystem] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [VotingSystem] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [VotingSystem] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [VotingSystem] SET  ENABLE_BROKER 
GO
ALTER DATABASE [VotingSystem] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [VotingSystem] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [VotingSystem] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [VotingSystem] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [VotingSystem] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [VotingSystem] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [VotingSystem] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [VotingSystem] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [VotingSystem] SET  MULTI_USER 
GO
ALTER DATABASE [VotingSystem] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [VotingSystem] SET DB_CHAINING OFF 
GO
ALTER DATABASE [VotingSystem] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [VotingSystem] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [VotingSystem] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [VotingSystem] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [VotingSystem] SET QUERY_STORE = ON
GO
ALTER DATABASE [VotingSystem] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Candidates]

-- %%
USE [VotingSystem]
GO

-- %%
/****** Object:  Table [dbo].[Candidates]    Script Date: 3/25/2025 5:25:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Candidates](
	[candidate_id] [int] IDENTITY(1,1) NOT NULL,
	[full_name] [varchar](100) NOT NULL,
	[candidate_position] [varchar](50) NOT NULL,
	[election_id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[candidate_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Elections]

-- %%
/****** Object:  Table [dbo].[Elections]    Script Date: 3/25/2025 5:25:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Elections](
	[election_id] [int] IDENTITY(1,1) NOT NULL,
	[election_name] [varchar](100) NOT NULL,
	[election_date] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[election_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Students]

-- %%
/****** Object:  Table [dbo].[Students]    Script Date: 3/25/2025 5:25:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Students](
	[student_id] [varchar](20) NOT NULL,
	[full_name] [varchar](100) NOT NULL,
	[department] [varchar](50) NOT NULL,
	[has_voted] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[student_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Votes]

-- %%
/****** Object:  Table [dbo].[Votes]    Script Date: 3/25/2025 5:25:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Votes](
	[vote_id] [int] IDENTITY(1,1) NOT NULL,
	[student_id] [varchar](20) NOT NULL,
	[candidate_id] [int] NOT NULL,
	[election_id] [int] NOT NULL,
	[vote_timestamp] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[vote_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [unique_vote] UNIQUE NONCLUSTERED 
(
	[student_id] ASC,
	[election_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Students__has_vo__49C3F6B7]

-- %%
ALTER TABLE [dbo].[Students] ADD  DEFAULT ((0)) FOR [has_voted]
GO

-- %% [markdown]
-- # [DF__Votes__vote_time__59063A47]

-- %%
ALTER TABLE [dbo].[Votes] ADD  DEFAULT (getdate()) FOR [vote_timestamp]
GO

-- %% [markdown]
-- # [FK__Candidate__elect__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Candidates]  WITH CHECK ADD FOREIGN KEY([election_id])
REFERENCES [dbo].[Elections] ([election_id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Votes__candidate__5AEE82B9]

-- %%
ALTER TABLE [dbo].[Votes]  WITH CHECK ADD FOREIGN KEY([candidate_id])
REFERENCES [dbo].[Candidates] ([candidate_id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Votes__election___5BE2A6F2]

-- %%
ALTER TABLE [dbo].[Votes]  WITH CHECK ADD FOREIGN KEY([election_id])
REFERENCES [dbo].[Elections] ([election_id])
GO

-- %% [markdown]
-- # [FK__Votes__student_i__59FA5E80]

-- %%
ALTER TABLE [dbo].[Votes]  WITH CHECK ADD FOREIGN KEY([student_id])
REFERENCES [dbo].[Students] ([student_id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [VotingSystem]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [VotingSystem] SET  READ_WRITE 
GO
